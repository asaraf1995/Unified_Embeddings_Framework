# %%
begin = datetime.datetime.now()

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras as keras
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model
from keras.layers import Activation, Dense, Dropout, Input
from keras import optimizers, regularizers
from sklearn.metrics import confusion_matrix,accuracy_score, roc_curve, auc
from sklearn import preprocessing
import mysql.connector

#Data Import
conn = mysql.connector.connect(user='root', password='Kunwar_IIT13',
                               host='127.0.0.1',
                               database='database_schema')
cursor = conn.cursor()
query = 'select * from ml_temp'
results = pd.read_sql_query(query, conn)
results.to_csv("ml_temp1.csv", index=False)
data = pd.read_csv('ml_temp1.csv')
user_id = data["userid"]

#remove unnecessary variables
df = data.drop(['userid'], axis = 1)
list_of_column_names = list(df.columns)

# %%
#Encode categorical data to ONE-HOT
categorical_data = ['gender']
df = pd.get_dummies(df, columns = categorical_data)

# %%
#Scale the data to [0,1] range
columns_to_scale = list_of_column_names
df2 = pd.DataFrame(np.random.randint(12,1000,size= (len(user_id), 199)), columns = list_of_column_names)
df2[columns_to_scale]=df2[columns_to_scale].apply(lambda x: (x-x.min())/(x.max()-x.min()))

# %%
#Split in 75% train and 25% test set
X = df2.iloc[:, :]
X_train, X_test, y_train, y_test = train_test_split(X, X, test_size=0.2, random_state=2)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (945, 199) (237, 199) (945, 199) (237, 199)

# %%
# reduce to 32 features
encoding_dim = 32

input_df = Input(shape=(X_train.shape[1],))
encoded = Dense(encoding_dim, activation='relu')(input_df)
decoded = Dense(X_train.shape[1], activation='sigmoid')(encoded)

# encoder
autoencoder = Model(input_df, decoded)

autoencoder.compile(optimizer='adam', loss='mean_squared_logarithmic_error')
# autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
autoencoder_model = autoencoder.fit(X_train, X_train,
                epochs=200,
                batch_size=100,
                shuffle=True,
                validation_data=(X_test, X_test))

# Summarize history for loss
plt.figure()
plt.plot(autoencoder_model.history['loss'])
plt.plot(autoencoder_model.history['val_loss'])
plt.title('Autoencoder model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 80ms/step - loss: 0.0402 - val_loss: 0.0397
# Epoch 2/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0394 - val_loss: 0.0397
# Epoch 3/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0394 - val_loss: 0.0396
# Epoch 4/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0395 - val_loss: 0.0395
# Epoch 5/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0393 - val_loss: 0.0395
# Epoch 6/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0391 - val_loss: 0.0394
# Epoch 7/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0392 - val_loss: 0.0393
# Epoch 8/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0390 - val_loss: 0.0392
# Epoch 9/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0389 - val_loss: 0.0391
# Epoch 10/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0386 - val_loss: 0.0389
# Epoch 11/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0384 - val_loss: 0.0388
# Epoch 12/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0383 - val_loss: 0.0387
# Epoch 13/200
# 10/10 [==============================] - 0s 14ms/step - loss: 0.0381 - val_loss: 0.0385
# Epoch 14/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0378 - val_loss: 0.0384
# Epoch 15/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0376 - val_loss: 0.0382
# Epoch 16/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0374 - val_loss: 0.0380
# Epoch 17/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0372 - val_loss: 0.0378
# Epoch 18/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0369 - val_loss: 0.0377
# Epoch 19/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0367 - val_loss: 0.0375
# Epoch 20/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0365 - val_loss: 0.0374
# Epoch 21/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0365 - val_loss: 0.0373
# Epoch 22/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0362 - val_loss: 0.0372
# Epoch 23/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0361 - val_loss: 0.0371
# Epoch 24/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0358 - val_loss: 0.0370
# Epoch 25/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0358 - val_loss: 0.0369
# Epoch 26/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0357 - val_loss: 0.0368
# Epoch 27/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0357 - val_loss: 0.0368
# Epoch 28/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0354 - val_loss: 0.0367
# Epoch 29/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0354 - val_loss: 0.0366
# Epoch 30/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0352 - val_loss: 0.0366
# Epoch 31/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0352 - val_loss: 0.0365
# Epoch 32/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0350 - val_loss: 0.0364
# Epoch 33/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0348 - val_loss: 0.0363
# Epoch 34/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0346 - val_loss: 0.0362
# Epoch 35/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0346 - val_loss: 0.0361
# Epoch 36/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0346 - val_loss: 0.0360
# Epoch 37/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0345 - val_loss: 0.0360
# Epoch 38/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0343 - val_loss: 0.0359
# Epoch 39/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0341 - val_loss: 0.0359
# Epoch 40/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0341 - val_loss: 0.0358
# Epoch 41/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0340 - val_loss: 0.0357
# Epoch 42/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0339 - val_loss: 0.0357
# Epoch 43/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0338 - val_loss: 0.0357
# Epoch 44/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0337 - val_loss: 0.0356
# Epoch 45/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0337 - val_loss: 0.0356
# Epoch 46/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0336 - val_loss: 0.0356
# Epoch 47/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0336 - val_loss: 0.0355
# Epoch 48/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0334 - val_loss: 0.0355
# Epoch 49/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0334 - val_loss: 0.0355
# Epoch 50/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0334 - val_loss: 0.0355
# Epoch 51/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0334 - val_loss: 0.0355
# Epoch 52/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0333 - val_loss: 0.0354
# Epoch 53/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0333 - val_loss: 0.0354
# Epoch 54/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0333 - val_loss: 0.0354
# Epoch 55/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0332 - val_loss: 0.0354
# Epoch 56/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0331 - val_loss: 0.0354
# Epoch 57/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0331 - val_loss: 0.0354
# Epoch 58/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0330 - val_loss: 0.0354
# Epoch 59/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0332 - val_loss: 0.0353
# Epoch 60/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0329 - val_loss: 0.0353
# Epoch 61/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0329 - val_loss: 0.0353
# Epoch 62/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0329 - val_loss: 0.0353
# Epoch 63/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0329 - val_loss: 0.0353
# Epoch 64/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0329 - val_loss: 0.0353
# Epoch 65/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0329 - val_loss: 0.0353
# Epoch 66/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0328 - val_loss: 0.0353
# Epoch 67/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0327 - val_loss: 0.0353
# Epoch 68/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0328 - val_loss: 0.0352
# Epoch 69/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0327 - val_loss: 0.0352
# Epoch 70/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0353
# Epoch 71/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0352
# Epoch 72/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0352
# Epoch 73/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0352
# Epoch 74/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0327 - val_loss: 0.0352
# Epoch 75/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0352
# Epoch 76/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0352
# Epoch 77/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0352
# Epoch 78/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0352
# Epoch 79/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0352
# Epoch 80/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0352
# Epoch 81/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0352
# Epoch 82/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0326 - val_loss: 0.0352
# Epoch 83/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0352
# Epoch 84/200
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0324 - val_loss: 0.0352
# Epoch 85/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0324 - val_loss: 0.0352
# Epoch 86/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0352
# Epoch 87/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0325 - val_loss: 0.0352
# Epoch 88/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0324 - val_loss: 0.0352
# Epoch 89/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0324 - val_loss: 0.0352
# Epoch 90/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0352
# Epoch 91/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0352
# Epoch 92/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0352
# Epoch 93/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0352
# Epoch 94/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0324 - val_loss: 0.0352
# Epoch 95/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0352
# Epoch 96/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0352
# Epoch 97/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0352
# Epoch 98/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0323 - val_loss: 0.0352
# Epoch 99/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0352
# Epoch 100/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0322 - val_loss: 0.0352
# Epoch 101/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0352
# Epoch 102/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0321 - val_loss: 0.0351
# Epoch 103/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0322 - val_loss: 0.0352
# Epoch 104/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0322 - val_loss: 0.0352
# Epoch 105/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0322 - val_loss: 0.0352
# Epoch 106/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0352
# Epoch 107/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0321 - val_loss: 0.0352
# Epoch 108/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0351
# Epoch 109/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0352
# Epoch 110/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 111/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0322 - val_loss: 0.0351
# Epoch 112/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0352
# Epoch 113/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0321 - val_loss: 0.0351
# Epoch 114/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0322 - val_loss: 0.0352
# Epoch 115/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0351
# Epoch 116/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 117/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 118/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 119/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0321 - val_loss: 0.0351
# Epoch 120/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 121/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0321 - val_loss: 0.0351
# Epoch 122/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 123/200
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 124/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 125/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 126/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 127/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0321 - val_loss: 0.0351
# Epoch 128/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 129/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 130/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 131/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 132/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 133/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 134/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 135/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 136/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 137/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0320 - val_loss: 0.0351
# Epoch 138/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 139/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 140/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 141/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 142/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 143/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 144/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 145/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 146/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 147/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 148/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 149/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 150/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 151/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 152/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 153/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 154/200
# 10/10 [==============================] - 0s 15ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 155/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 156/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 157/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 158/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0319 - val_loss: 0.0351
# Epoch 159/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 160/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 161/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 162/200
# 10/10 [==============================] - 0s 12ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 163/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 164/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 165/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 166/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 167/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 168/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 169/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0318 - val_loss: 0.0351
# Epoch 170/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 171/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 172/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 173/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 174/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 175/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 176/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 177/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 178/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 179/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 180/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 181/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 182/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 183/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 184/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0315 - val_loss: 0.0351
# Epoch 185/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 186/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 187/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 188/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 189/200
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 190/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 191/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0317 - val_loss: 0.0351
# Epoch 192/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 193/200
# 10/10 [==============================] - 0s 13ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 194/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0351
# Epoch 195/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 196/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 197/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0315 - val_loss: 0.0351
# Epoch 198/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 199/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0316 - val_loss: 0.0351
# Epoch 200/200
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0314 - val_loss: 0.0351

# %%
encoder = Model(input_df, encoded)
encoded_x = encoder.predict(X)
new_table = []
for i in range(len(encoded_x)):
    new_table.append([(user_id[i]), str(encoded_x[i])])

# %%
# import mysql.connector
# from mysql.connector import errorcode
#
# try:
#     cnx = mysql.connector.connect(user='root', password='Kunwar_IIT13',
#                                  host='127.0.0.1',
#                                  database='database_schema')
# except mysql.connector.Error as err:
#     if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
#         print("Something is wrong with your user name or password")
#     elif err.errno == errorcode.ER_BAD_DB_ERROR:
#         print("Database does not exist")
#     else:
#         print(err)
# else:
cursor = conn.cursor()
cursor.execute("DROP TABLE IF EXISTS embeddings_table")
cursor.execute("CREATE TABLE `embeddings_table` ("
"  `User_id` int NOT NULL, `Embeddings` VARCHAR(1000))")
for i in range(len(new_table)):
    # print(new_table[i][0], new_table[i][1])
#         data = (new_table[i][0] , str(new_table[i][1]))
#         print(data)
    insert_query = "INSERT INTO embeddings_table (User_id, Embeddings) VALUES (%s, %s)"
    cursor.execute(insert_query, (int(new_table[i][0]), str(new_table[i][1])))
conn.commit()
